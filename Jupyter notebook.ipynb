# %% [markdown]
# ### This notebook is mainly useful for the Capstone project.Generally in this project it mainly goes with the geographical location and getting the better results for given location details.In this final project,every peer must select his best problem statement and have to work on it using data analysis,data visualization and python for data science.In this way this jupyter notebook is useful in finishing the capstone project.

# %%
import pandas as pd

# %%
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
